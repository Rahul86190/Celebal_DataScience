# %% [markdown]
# ## Matplot

# %% [markdown]
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
#
# Matplotlib was created by John D. Hunter.
#
# Matplotlib is open source and we can use it freely.
#
# Matplotlib is mostly written in python, a few segments are written in C, Objective-C and Javascript for Platform compatibility.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Plotting in matplot

a=[1,5,2,9,4,0,12,65,2,7]
plt.plot(a)
plt.show()

# %%
marks=[67,89,90,83,79]
Subject=["Physics","Mathematics","Chemistry","Hindi","English"]
plt.plot(Subject,marks)
plt.show()

# %%
price=[20,50,100,500,200,100]
Year=[2020,2021,2022,2023,2024,2025]
plt.plot(Year,price)
plt.ylabel("Price of Milk")
plt.xlabel("Year")
plt.show()

# %%
a=np.random.randint(0,100,40)
plt.plot(a)
plt.show()

# %%
a=np.random.randint(0,100,40)
plt.plot(a,"v")
plt.show()

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
xpoints = np.array([1,3,5,8,18])
ypoints = np.array([3,5,7,9, 10])

plt.plot(xpoints, ypoints,marker='P')
plt.show()

# %% [markdown]
# ##  Marker types
#
# 'o'	Circle
#
# '*'	Star
#
# '.'	Point
#
# ','	Pixel
#
# 'x'	X
#
# 'X'	X (filled)
#
# '+'	Plus
#
# 'P'	Plus (filled)
#
# 's'	Square
#
# 'D'	Diamond
#
# 'd'	Diamond (thin)
#
# 'p'	Pentagon
#
# 'H'	Hexagon
#
# 'h'	Hexagon
#
# 'v'	Triangle Down
#
# '^'	Triangle Up
#
# '<'	Triangle Left
#
# '>'	Triangle Right
#
# '1'	Tri Down
#
# '2'	Tri Up
#
# '3'	Tri Left
#
# '4'	Tri Right
#
# '|'	Vline
#
# '_'	Hline

# %% [markdown]
# ## Format Strings fmt
# You can also use the shortcut string notation parameter to specify the marker.
#
# This parameter is also called fmt, and is written with this syntax:
#
# marker|line|color

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')          # o marker, : dotted line, r Red line
plt.show()

# %% [markdown]
# ## Colors
# 'r'	Red
#
# 'g'	Green
#
# 'b'	Blue
#
# 'c'	Cyan
#
# 'm'	Magenta
#
# 'y'	Yellow
#
# 'k'	Black
#
# 'w'	White

# %% [markdown]
# ## Lines
# '-'	Solid line
#
# ':'	Dotted line
#
# '--'	Dashed line
#
# '-.'	Dashed/dotted line

# %% [markdown]
# Use more Marker Attribute Like marker size, marker edge color, marker face color

# %%
xpoints = np.array([1,3,5,8,18])
ypoints = np.array([3,5,7,9, 10])

plt.plot(xpoints, ypoints,marker='P',ms=10)
plt.show()

# %%
xpoints = np.array([1,3,5,8,18])
ypoints = np.array([3,5,7,9, 10])

plt.plot(xpoints, ypoints,marker='P',ms=20,mec="r")
plt.show()

# %%
xpoints = np.array([1,3,5,8,18])
ypoints = np.array([3,5,7,9, 10])

plt.plot(xpoints, ypoints,marker='H',ms=20,mec="r",mfc="hotpink")
plt.show()

# %% [markdown]
# ## 1. Line Plot

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, ls = '--',c="Red")
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, ls='dashdot', c='#20B2AA',lw=12)
plt.show()

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])
x1=[2020,2022,2023,2025]
x2=[1955,1970,2000,2015]
font2 = {'family':'serif','color':'darkred','size':15}
plt.title("Lines",loc="left",font='Arial')
plt.xlabel("Year",font="serif")
plt.ylabel("sales",fontdict=font2)
plt.plot(x1,y1)
plt.plot(x2,y2)

plt.show()

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.show()

# %%
a = np.array([3, 8, 1, 10])
b = np.array([6, 2, 7, 11])
plt.subplot(1,2,1)   # 1st row 2nd column 1st chart
plt.plot(a)
plt.subplot(1,2,2)  # 1st row 2nd column 2nd chart
plt.plot(b)
plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# ## Scatter plot

# %% [markdown]
# The scatter() function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y,marker="p",)
plt.show()

# %%
# Compare Plots

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y,c="Red")

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y,c="purple")

plt.show()

# %% [markdown]
# Note: You cannot use the color argument for this, only the c argument.

# %% [markdown]
# Color each dot

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

# %% [markdown]
# ## Color Map

# %% [markdown]
# The Matplotlib module has a number of available colormaps.
#
# A colormap is like a list of colors, where each color has a value that ranges from 0 to 100.

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
plt.figure(figsize=(12,8))
plt.subplot(3,3,1)
plt.scatter(x, y, c=colors, cmap='winter')
plt.colorbar()

plt.subplot(3,3,2)
plt.scatter(x, y, c=colors, cmap='twilight')
plt.colorbar()

plt.subplot(3,3,3)
plt.scatter(x, y, c=colors, cmap='tab20')
plt.colorbar()

plt.subplot(3,3,4)
plt.scatter(x, y, c=colors, cmap='spring')
plt.colorbar()

plt.subplot(3,3,5)
plt.scatter(x, y, c=colors, cmap='plasma')
plt.colorbar()

plt.subplot(3,3,6)
plt.scatter(x, y, c=colors, cmap='prism')
plt.colorbar()

plt.subplot(3,3,7)
plt.scatter(x, y, c=colors, cmap='rainbow')
plt.colorbar()

plt.subplot(3,3,8)
plt.scatter(x, y, c=colors, cmap='seismic')
plt.colorbar()

plt.subplot(3,3,9)
plt.scatter(x, y, c=colors, cmap='gnuplot')
plt.colorbar()


plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
plt.figure(figsize=(12,8))
plt.subplot(3,3,1)
plt.scatter(x, y, c=colors, cmap='gist_earth')
plt.colorbar()

plt.subplot(3,3,2)
plt.scatter(x, y, c=colors, cmap='cubehelix')
plt.colorbar()

plt.subplot(3,3,3)
plt.scatter(x, y, c=colors, cmap='cividis')
plt.colorbar()

plt.subplot(3,3,4)
plt.scatter(x, y, c=colors, cmap='RdYlBu')
plt.colorbar()

plt.subplot(3,3,5)
plt.scatter(x, y, c=colors, cmap='ocean')
plt.colorbar()

plt.subplot(3,3,6)
plt.scatter(x, y, c=colors, cmap='jet')
plt.colorbar()

plt.subplot(3,3,7)
plt.scatter(x, y, c=colors, cmap='hsv')
plt.colorbar()


plt.subplot(3,3,8)
plt.scatter(x, y, c=colors, cmap='Pastel1')
plt.colorbar()

plt.subplot(3,3,9)
plt.scatter(x, y, c=colors, cmap='PuBuGn')
plt.colorbar()


plt.show()

# %% [markdown]
# We can change the size of the dots with the s argument.

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %% [markdown]
# We can adjust the transparency of the dots with the alpha argument.

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# ### Bar Chart

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, color = "red")
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.1)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.1)
plt.show()

# %% [markdown]
# ## Histograms

# %% [markdown]
# A histogram is a graph showing frequency distributions.
#
# It is a graph showing the number of observations within each given interval

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# ## Pie Charts

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %% [markdown]
# Explode

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# Shadow

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# Colors

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# ## Legend
# To add a list of explanation for each wedge, use the legend()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()
